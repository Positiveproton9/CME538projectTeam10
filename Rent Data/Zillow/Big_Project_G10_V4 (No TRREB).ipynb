# %% [markdown]
# # Big Project
# ## Group 10 - Data Under Construction

# %% [markdown]
# ### Setup Notebook

# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\omar\anaconda3\lib\site-packages (0.14.2)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\omar\anaconda3\lib\site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in c:\users\omar\anaconda3\lib\site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\omar\anaconda3\lib\site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\omar\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\omar\anaconda3\lib\site-packages (from geopandas) (2.0.5)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\omar\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (23.1.0)
# Requirement already satisfied: certifi in c:\users\omar\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2024.8.30)
# Requirement already satisfied: click~=8.0 in c:\users\omar\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\omar\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\omar\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\omar\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\omar\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (69.5.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\omar\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\omar\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\omar\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\omar\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: colorama in c:\users\omar\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)

# %%
# !pip install haversine
# Out:
# Requirement already satisfied: haversine in c:\users\omar\anaconda3\lib\site-packages (2.9.0)

# %%
# Import 3rd party libraries
import os
import json
import requests
import numpy as np
import pandas as pd
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
import matplotlib.patches as mpatches

# Configure Notebook
# %matplotlib inline 
plt.style.use('seaborn-v0_8-ticks')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold, TimeSeriesSplit
from sklearn.base import clone

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.model_selection import cross_val_score, cross_validate

# %%
from haversine import haversine

# %% [markdown]
# ### 1. Collecting and Cleaning Data

# %% [markdown]
# #### 1.1 Neighbourhoods Data

# %% [markdown]
# First, we need the Toronto Neighborhoods geodata to locate the different listings in their specific neighborhoods. To do so, we will use the Boundaries of Toronto Neighbourhoods files from Toronto Open Data.

# %%
# Load the shapefile (use the path to the .shp file)
neighbourhoods = gpd.read_file('Neighbourhoods - 4326.shp')

# %%
# Display the first few rows of the neighbourhoods GeoDataFrame
neighbourhoods.head()
# Out:
#    _id1  AREA_ID2  AREA_AT3  PARENT_4 AREA_SH5 AREA_LO6  \
# 0     1   2502366  26022881         0      174      174
# 1     2   2502365  26022880         0      173      173
# 2     3   2502364  26022879         0      172      172
# 3     4   2502363  26022878         0      171      171
# 4     5   2502362  26022877         0      170      170
#
#                     AREA_NA7                         AREA_DE8  \
# 0  South Eglinton-Davisville  South Eglinton-Davisville (174)
# 1              North Toronto              North Toronto (173)
# 2         Dovercourt Village         Dovercourt Village (172)
# 3   Junction-Wallace Emerson   Junction-Wallace Emerson (171)
# 4         Yonge-Bay Corridor         Yonge-Bay Corridor (170)
#
#                                CLASSIF9 CLASSIF10   OBJECTI11  \
# 0  Not an NIA or Emerging Neighbourhood        NA  17824737.0
# 1  Not an NIA or Emerging Neighbourhood        NA  17824753.0
# 2  Not an NIA or Emerging Neighbourhood        NA  17824769.0
# 3  Not an NIA or Emerging Neighbourhood        NA  17824785.0
# 4  Not an NIA or Emerging Neighbourhood        NA  17824801.0
#
#                                             geometry
# 0  POLYGON ((-79.38635 43.69783, -79.38623 43.697...
# 1  POLYGON ((-79.39744 43.70693, -79.39837 43.706...
# 2  POLYGON ((-79.43411 43.66015, -79.43537 43.659...
# 3  POLYGON ((-79.43870 43.66766, -79.43841 43.666...
# 4  POLYGON ((-79.38404 43.64497, -79.38502 43.644...

# %%
# Plot the neighborhoods
fig, ax = plt.subplots(figsize=(12, 12))
neighbourhoods.plot(ax=ax, color='lightblue', edgecolor='white')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.show()

# %% [markdown]
# Next, we will create a dictionary for the ranking of neighborhoods. This ranking is from the Toronto Life website, and it is based on 10 different factors as shown below.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Define the neighborhood ranking as a dictionary
neighbourhood_ranking = {
    'Danforth': 1,
    'West Queen West': 2,
    'Runnymede-Bloor West Village': 3,
    'Avondale': 4,
    'Wellington Place': 5,
    'Yonge-Doris': 6,
    'Cabbagetown-South St.James Town': 7,
    'Bay-Cloverhill': 8,
    'Palmerston-Little Italy': 9,
    'Trinity-Bellwoods': 10,
    'Bridle Path-Sunnybrook-York Mills': 11,
    'Annex': 12,
    'North Riverdale': 13,
    'Mount Pleasant East': 14,
    'Lawrence Park North': 15,
    'Kingsway South': 16,
    'University': 17,
    'Yonge-Bay Corridor': 18,
    'Leaside-Bennington': 19,
    'South Eglinton-Davisville': 20,
    'Harbourfront-CityPlace': 21,
    'Wychwood': 22,
    'Dovercourt Village': 23,
    'Blake-Jones': 24,
    'Roncesvalles': 25,
    'Dufferin Grove': 26,
    'Lawrence Park South': 27,
    'Church-Wellesley': 28,
    'Casa Loma': 29,
    'Woodbine-Lumsden': 30,
    'Danforth East York': 31,
    'Regent Park': 32,
    'Lansing-Westgate': 33,
    'Downtown Yonge East': 34,
    'St Lawrence-East Bayfront-The Islands': 35,
    'Yonge-Eglinton': 36,
    'High Park-Swansea': 37,
    'Little Portugal': 38,
    'Forest Hill South': 39,
    'Playter Estates-Danforth': 40,
    'Junction Area': 41,
    'Woodbine Corridor': 42,
    'The Beaches': 43,
    'Rosedale-Moore Park': 44,
    'Old East York': 45,
    'Bedford Park-Nortown': 46,
    'High Park North': 47,
    'Kensington-Chinatown': 48,
    'Yonge-St.Clair': 49,
    'Junction-Wallace Emerson': 50,
    'Princess-Rosethorn': 51,
    'Fort York-Liberty Village': 52,
    'North St.James Town': 53,
    'Willowdale West': 54,
    'North Toronto': 55,
    'Greenwood-Coxwell': 56,
    'Bayview Village': 57,
    'South Riverdale': 58,
    'Humewood-Cedarvale': 59,
    'East End-Danforth': 60,
    'Taylor-Massey': 61,
    'East Willowdale': 62,
    'Corso Italia-Davenport': 63,
    'Etobicoke City Centre': 64,
    'Stonegate-Queensway': 65,
    'Centennial Scarborough': 66,
    'Hillcrest Village': 67,
    'Humber Bay Shores': 68,
    'Moss Park': 69,
    'Broadview North': 70,
    'Morningside Heights': 71,
    'Lambton Baby Point': 72,
    'Newtonbrook East': 73,
    'Malvern West': 74,
    'Forest Hill North': 75,
    'Clanton Park': 76,
    'Pleasant View': 77,
    'Banbury-Don Mills': 78,
    'Malvern East': 79,
    'Islington': 80,
    'Markland Wood': 81,
    'Highland Creek': 82,
    'Agincourt North': 83,
    'Edenbridge-Humber Valley': 84,
    'East L\'Amoreaux': 85,
    'Alderwood': 86,
    'Milliken': 87,
    'Henry Farm': 88,
    'Steeles': 89,
    'St.Andrew-Windfields': 90,
    'Pelmo Park-Humberlea': 91,
    'Guildwood': 92,
    'Oakwood Village': 93,
    'Agincourt South-Malvern West': 94,
    'Birchcliffe-Cliffside': 95,
    'Clairlea-Birchmount': 96,
    'Englemount-Lawrence': 97,
    'West Rouge': 98,
    'Tam O\'Shanter-Sullivan': 99,
    'Briar Hill-Belgravia': 100,
    'Bayview Woods-Steeles': 101,
    'Weston-Pelham Park': 102,
    'Bathurst Manor': 103,
    'Woburn North': 104,
    'Bendale South': 105,
    'Newtonbrook West': 106,
    'L\'Amoreaux West': 107,
    'Eringate-Centennial-West Deane': 108,
    'Flemingdon Park': 109,
    'Westminster-Branson': 110,
    'Don Valley Village': 111,
    'Long Branch': 112,
    'Caledonia-Fairbank': 113,
    'Humber Heights-Westmount': 114,
    'Parkwoods-O\'Connor Hills': 115,
    'Rockcliffe-Smythe': 116,
    'Thistletown-Beaumond Heights': 117,
    'Keelesdale-Eglinton West': 118,
    'Maple Leaf': 119,
    'O\'Connor-Parkview': 120,
    'Etobicoke West Mall': 121,
    'Morningside': 122,
    'Mimico-Queensway': 123,
    'Bendale-Glen Andrew': 124,
    'Oakridge': 125,
    'Dorset Park': 126,
    'Thorncliffe Park': 127,
    'Wexford/Maryvale': 128,
    'Victoria Village': 129,
    'Elms-Old Rexdale': 130,
    'Cliffcrest': 131,
    'Humbermede': 132,
    'Mount Dennis': 133,
    'Ionview': 134,
    'Willowridge-Martingrove-Richview': 135,
    'Downsview': 136,
    'Kingsview Village-The Westway': 137,
    'Eglinton East': 138,
    'Fenside-Parkwoods': 139,
    'Yorkdale-Glen Park': 140,
    'Mount Olive-Silverstone-Jamestown': 141,
    'West Humber-Clairville': 142,
    'Glenfield-Jane Heights': 143,
    'South Parkdale': 144,
    'York University Heights': 145,
    'New Toronto': 146,
    'Golfdale-Cedarbrae-Woburn': 147,
    'Brookhaven-Amesbury': 148,
    'Rexdale-Kipling': 149,
    'Rustic': 150,
    'Humber Summit': 151,
    'Scarborough Village': 152,
    'Beechborough-Greenbrook': 153,
    'Oakdale-Beverley Heights': 154,
    'Weston': 155,
    'West Hill': 156,
    'Black Creek': 157,
    'Kennedy Park': 158
}

# %% [markdown]
# #### 1.2 Zillow Rent Data

# %% [markdown]
# Zillow website offers many csv files for rental listings. Five files were imported as shown below.

# %%
# Load each CSV file
zillow_one = pd.read_csv('zillow-one.csv')
zillow_two = pd.read_csv('zillow-two.csv')
zillow_three = pd.read_csv('zillow-three.csv')

# %%
zillow_one.head()
# Out:
#                                         Property URL Property type  \
# 0  https://www.zillow.com/homedetails/413-Markham...     Apartment
# 1  https://www.zillow.com/homedetails/1221-King-S...     Apartment
# 2  https://www.zillow.com/homedetails/47-Lower-Ri...     Apartment
# 3  https://www.zillow.com/b/1350-ellesmere-rd-tor...      Building
# 4  https://www.zillow.com/b/1350-ellesmere-rd-tor...     Apartment
#
#    Number of days on Zillow Date listed (MM/DD/YYYY)  \
# 0                       2.0               11/04/2024
# 1                       2.0               11/04/2024
# 2                       2.0               11/04/2024
# 3                       3.0               11/03/2024
# 4                       NaN                      NaN
#
#    Rental price (USD per month)  Living area Living area unit  \
# 0                        2400.0        900.0             sqft
# 1                        2200.0        500.0             sqft
# 2                        2200.0        500.0             sqft
# 3                           NaN          NaN              NaN
# 4                        2200.0          NaN              NaN
#
#    Price per living area unit (USD)  Bedrooms  Bathrooms  ...  \
# 0                              2.67       1.0        1.0  ...
# 1                              4.40       1.0        1.0  ...
# 2                              4.40       1.0        1.0  ...
# 3                               NaN       NaN        NaN  ...
# 4                               NaN       1.0        NaN  ...
#
#   Property unit number     Street address     City Zip   Latitude  Longitude  \
# 0                  NaN     413 Markham St  Toronto NaN  43.660350 -79.410310
# 1               # 7026     1221 King St W  Toronto NaN  43.638584 -79.427666
# 2                  NaN  47 Lower River St  Toronto NaN  43.656498 -79.355540
# 3                  NaN  1350 Ellesmere Rd  Toronto NaN  43.770374 -79.261860
# 4                  NaN  1350 Ellesmere Rd  Toronto NaN        NaN        NaN
#
#     Zillow property ID  Property is a building  \
# 0           2063459583                     NaN
# 1           2054131263                     NaN
# 2           2079696219                     NaN
# 3  43.770374--79.26186                     Yes
# 4                  NaN                      No
#
#                                        Building name Unit availability count
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3  Red-Three Building (Randomly generated buildin...                     3.0
# 4                Unit located in: Red-Three Building                     NaN
#
# [5 rows x 23 columns]

# %%
zillow_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188 entries, 0 to 1187
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Property URL                      1188 non-null   object
#  1   Property type                     1188 non-null   object
#  2   Number of days on Zillow          736 non-null    float64
#  3   Date listed (MM/DD/YYYY)          736 non-null    object
#  4   Rental price (USD per month)      819 non-null    float64
#  5   Living area                       95 non-null     float64
#  6   Living area unit                  95 non-null     object
#  7   Price per living area unit (USD)  95 non-null     float64
#  8   Bedrooms                          819 non-null    float64
#  9   Bathrooms                         450 non-null    float64
#  10  Image URL                         811 non-null    object
#  11  Is owner occupied                 450 non-null    object
#  12  Property owned by Zillow          450 non-null    object
#  13  Property unit number              373 non-null    object
#  14  Street address                    1183 non-null   object
#  15  City                              1188 non-null   object
#  16  Zip                               0 non-null      float64
#  17  Latitude                          814 non-null    float64
#  18  Longitude                         814 non-null    float64
#  19  Zillow property ID                819 non-null    object
#  20  Property is a building            738 non-null    object
#  21  Building name                     738 non-null    object
#  22  Unit availability count           369 non-null    float64
# dtypes: float64(10), object(13)
# memory usage: 213.6+ KB

# %%
def filter_zillow(df):
    # Filter the DataFrame to keep only rows with non-null values in the "Living area" column and "latitude" column
    Zillow_filtered = df[df['Living area'].notnull()]
    Zillow_filtered = Zillow_filtered.dropna(subset=['Latitude'])

    # Select only specific columns (Note that the rental price is in CAD but Zillow mistakenly write it in USD)
    Zillow_filtered = Zillow_filtered[['Rental price (USD per month)', 'Living area', 
                            'Bedrooms', 'Bathrooms', 'Street address', 'Latitude', 'Longitude','Zillow property ID']]

    # Rename specific columns
    Zillow_filtered = Zillow_filtered.rename(columns={'Rental price (USD per month)': 'Rent Price (CAD)',
                                                            'Living area': 'Living Area (sqft)',
                                                            'Street address': 'Address',
                                                            'Zillow property ID': 'Listing ID'})

    # Perform a spatial join to add the neighborhood name (from AREA_NA7) to each apartment
    geometry = [Point(xy) for xy in zip(Zillow_filtered['Longitude'], Zillow_filtered['Latitude'])]
    Zillow_filtered = gpd.GeoDataFrame(Zillow_filtered, geometry=geometry, crs='EPSG:4326')
    Zillow_hood = gpd.sjoin(Zillow_filtered, neighbourhoods, how="left", predicate="within")

    # Assign the neighborhood name from AREA_NA7 to a new column in the filtered DataFrame
    Zillow_filtered['Neighbourhood'] = Zillow_hood['AREA_NA7']

    # Map the ranks to the 'Neighbourhood' column in filtered_gdf
    Zillow_filtered['Neighbourhood Rank'] = Zillow_filtered['Neighbourhood'].map(neighbourhood_ranking)

    # Add 'Source' column
    Zillow_filtered['Source'] = 'Zillow'

    # Rearrange columns
    Zillow_filtered = Zillow_filtered[['Listing ID',
                                       'Source',
                                       'Address',
                                       'Bedrooms',
                                       'Bathrooms',
                                       'Living Area (sqft)',
                                       'Latitude',
                                       'Longitude',
                                       'Neighbourhood',
                                       'Neighbourhood Rank',
                                       'Rent Price (CAD)']]

    Zillow_filtered = Zillow_filtered.reset_index(drop=True)
    
    return Zillow_filtered

# %%
Zillow_one_filtered = filter_zillow(zillow_one)
Zillow_two_filtered = filter_zillow(zillow_two)
Zillow_three_filtered = filter_zillow(zillow_three)

# %%
# Display the filtered DataFrame info to verify
Zillow_one_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Listing ID          91 non-null     object
#  1   Source              91 non-null     object
#  2   Address             91 non-null     object
#  3   Bedrooms            91 non-null     float64
#  4   Bathrooms           91 non-null     float64
#  5   Living Area (sqft)  91 non-null     float64
#  6   Latitude            91 non-null     float64
#  7   Longitude           91 non-null     float64
#  8   Neighbourhood       91 non-null     object
#  9   Neighbourhood Rank  91 non-null     int64
#  10  Rent Price (CAD)    91 non-null     float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 7.9+ KB

# %%
# Display the filtered DataFrame info to verify
Zillow_two_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Listing ID          52 non-null     object
#  1   Source              52 non-null     object
#  2   Address             52 non-null     object
#  3   Bedrooms            52 non-null     float64
#  4   Bathrooms           52 non-null     float64
#  5   Living Area (sqft)  52 non-null     float64
#  6   Latitude            52 non-null     float64
#  7   Longitude           52 non-null     float64
#  8   Neighbourhood       52 non-null     object
#  9   Neighbourhood Rank  52 non-null     int64
#  10  Rent Price (CAD)    52 non-null     float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 4.6+ KB

# %%
# Display the filtered DataFrame info to verify
Zillow_three_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Listing ID          89 non-null     object
#  1   Source              89 non-null     object
#  2   Address             89 non-null     object
#  3   Bedrooms            89 non-null     float64
#  4   Bathrooms           89 non-null     float64
#  5   Living Area (sqft)  89 non-null     float64
#  6   Latitude            89 non-null     float64
#  7   Longitude           89 non-null     float64
#  8   Neighbourhood       89 non-null     object
#  9   Neighbourhood Rank  89 non-null     int64
#  10  Rent Price (CAD)    89 non-null     float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 7.8+ KB

# %% [markdown]
# #### 1.3 TRREB Rent Data

# %% [markdown]
# All TRREB rent data is dropped here.

# %% [markdown]
# #### 1.4 Rentals.ca Data

# %% [markdown]
# Refer to the Rentals.ca notebook for the process of collecting the TRREB Rent Data.

# %%
rentals = pd.read_csv('rentals_data_final.csv')

# %%
rentals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 759 entries, 0 to 758
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Listing price                    759 non-null    float64
#  1   Verified                         308 non-null    object
#  2   Updated                          169 non-null    object
#  3   Bed                              759 non-null    float64
#  4   Bathroom                         759 non-null    float64
#  5   sqft                             759 non-null    object
#  6   address                          759 non-null    object
#  7   listing-card__details-link href  759 non-null    object
#  8   City/Zone                        759 non-null    object
#  9   LAT                              759 non-null    float64
#  10  LONG                             759 non-null    float64
#  11  geometry                         759 non-null    object
#  12  Neighbourhood                    758 non-null    object
#  13  Neighbourhood Rank               758 non-null    float64
# dtypes: float64(6), object(8)
# memory usage: 83.1+ KB

# %%
# Select only specific columns
rentals_filtered = rentals[['Listing price', 'Bed', 'Bathroom', 'sqft', 'address',
                        'LAT', 'LONG','listing-card__details-link href', 'Neighbourhood','Neighbourhood Rank']]

# Rename specific columns
rentals_filtered = rentals_filtered.rename(columns={'Listing price': 'Rent Price (CAD)',
                                                'sqft': 'Living Area (sqft)',
                                                'address': 'Address',
                                                'listing-card__details-link href': 'Listing ID',
                                                'LAT': 'Latitude',
                                                'LONG': 'Longitude',
                                                'Bed': 'Bedrooms',
                                                'Bathroom': 'Bathrooms'})

# Add 'Source' column
rentals_filtered['Source'] = 'Rentals.ca'

# Rearrange columns
rentals_filtered = rentals_filtered[['Listing ID',
                                     'Source',
                                     'Address',
                                     'Bedrooms',
                                     'Bathrooms',
                                     'Living Area (sqft)',
                                     'Latitude',
                                     'Longitude',
                                     'Neighbourhood',
                                     'Neighbourhood Rank',
                                     'Rent Price (CAD)']]

rentals_filtered = rentals_filtered.dropna()

rentals_filtered = rentals_filtered.reset_index(drop=True)

# %%
# Display the filtered DataFrame info to verify
rentals_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Listing ID          758 non-null    object
#  1   Source              758 non-null    object
#  2   Address             758 non-null    object
#  3   Bedrooms            758 non-null    float64
#  4   Bathrooms           758 non-null    float64
#  5   Living Area (sqft)  758 non-null    object
#  6   Latitude            758 non-null    float64
#  7   Longitude           758 non-null    float64
#  8   Neighbourhood       758 non-null    object
#  9   Neighbourhood Rank  758 non-null    float64
#  10  Rent Price (CAD)    758 non-null    float64
# dtypes: float64(6), object(5)
# memory usage: 65.3+ KB

# %%
# Convert Living area from string to numeric 
rentals_filtered['Living Area (sqft)'] = rentals_filtered['Living Area (sqft)'].apply(lambda x: float(x.split(' - ')[0]) if ' - ' in x else float(x))

# %%
# Check the vaules in the 'Bedroom' column
rentals_filtered['Bedrooms'].value_counts()
# Out:
# Bedrooms
# 1.0    264
# 2.0    216
# 1.5    176
# 2.5     39
# 3.0     27
# 0.0     21
# 0.5     11
# 3.5      2
# 4.0      1
# 7.0      1
# Name: count, dtype: int64

# %%
# Drop all other than 1,1.5,2,2.5,3 bedrooms
rentals_filtered = rentals_filtered[rentals_filtered['Bedrooms'].isin([1, 1.5, 2, 2.5, 3])]

# %%
# Check the vaules in the 'Bedroom' column
rentals_filtered['Bedrooms'].value_counts()
# Out:
# Bedrooms
# 1.0    264
# 2.0    216
# 1.5    176
# 2.5     39
# 3.0     27
# Name: count, dtype: int64

# %%
# Check the vaules in the 'Bathrooms' column
rentals_filtered['Bathrooms'].value_counts()
# Out:
# Bathrooms
# 1.0    429
# 2.0    244
# 1.5     19
# 2.5     11
# 3.0     10
# 0.5      4
# 0.0      4
# 4.0      1
# Name: count, dtype: int64

# %%
rentals_filtered['Bathrooms'] = rentals_filtered['Bathrooms'].astype(float)

# %%
# Drop all other than 0.5,1,1.5,2,2.5,3 bathrooms
rentals_filtered = rentals_filtered[rentals_filtered['Bathrooms'].isin([1, 1.5, 2, 2.5, 3])]

# %%
# Check the vaules in the 'Bathrooms' column
rentals_filtered['Bathrooms'].value_counts()
# Out:
# Bathrooms
# 1.0    429
# 2.0    244
# 1.5     19
# 2.5     11
# 3.0     10
# Name: count, dtype: int64

# %%
rentals_filtered = rentals_filtered.reset_index(drop=True)

# %%
rentals_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Listing ID          713 non-null    object
#  1   Source              713 non-null    object
#  2   Address             713 non-null    object
#  3   Bedrooms            713 non-null    float64
#  4   Bathrooms           713 non-null    float64
#  5   Living Area (sqft)  713 non-null    float64
#  6   Latitude            713 non-null    float64
#  7   Longitude           713 non-null    float64
#  8   Neighbourhood       713 non-null    object
#  9   Neighbourhood Rank  713 non-null    float64
#  10  Rent Price (CAD)    713 non-null    float64
# dtypes: float64(7), object(4)
# memory usage: 61.4+ KB

# %% [markdown]
# #### 1.5 Combined Data

# %%
# Combine into one dataframe
combined_data = pd.concat([Zillow_one_filtered, Zillow_two_filtered, Zillow_three_filtered,
                           rentals_filtered], ignore_index=True)

# Display the combined DataFrame info to verify
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Listing ID          945 non-null    object
#  1   Source              945 non-null    object
#  2   Address             945 non-null    object
#  3   Bedrooms            945 non-null    float64
#  4   Bathrooms           945 non-null    float64
#  5   Living Area (sqft)  945 non-null    float64
#  6   Latitude            945 non-null    float64
#  7   Longitude           945 non-null    float64
#  8   Neighbourhood       945 non-null    object
#  9   Neighbourhood Rank  945 non-null    float64
#  10  Rent Price (CAD)    945 non-null    float64
# dtypes: float64(7), object(4)
# memory usage: 81.3+ KB

# %%
# Check the vaules in the 'Bedroom' column
combined_data['Bedrooms'].value_counts()
# Out:
# Bedrooms
# 1.0    354
# 2.0    266
# 1.5    171
# 3.0    115
# 2.5     39
# Name: count, dtype: int64

# %%
# Check the vaules in the 'Bathrooms' column
combined_data['Bathrooms'].value_counts()
# Out:
# Bathrooms
# 1.0    591
# 2.0    304
# 3.0     19
# 1.5     19
# 2.5     11
# 4.0      1
# Name: count, dtype: int64

# %%
# Drop 0, 3 and 4 bathrooms in 1 bedroom listings
combined_data = combined_data[~((combined_data['Bathrooms'].isin([0, 3, 4])) & (combined_data['Bedrooms'].isin([1, 1.5])))]
# Drop 4 bathrooms in listings
combined_data = combined_data[~(combined_data['Bathrooms'].isin([4]))]

# %%
# Check
combined_data['Bathrooms'].value_counts()
# Out:
# Bathrooms
# 1.0    591
# 2.0    304
# 3.0     19
# 1.5     19
# 2.5     11
# Name: count, dtype: int64

# %%
# Drop duplicates based on 'Address'
combined_data = combined_data.drop_duplicates(subset='Address', keep='first')

# %%
# Reset index
combined_data= combined_data.reset_index(drop=True)

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Listing ID          731 non-null    object
#  1   Source              731 non-null    object
#  2   Address             731 non-null    object
#  3   Bedrooms            731 non-null    float64
#  4   Bathrooms           731 non-null    float64
#  5   Living Area (sqft)  731 non-null    float64
#  6   Latitude            731 non-null    float64
#  7   Longitude           731 non-null    float64
#  8   Neighbourhood       731 non-null    object
#  9   Neighbourhood Rank  731 non-null    float64
#  10  Rent Price (CAD)    731 non-null    float64
# dtypes: float64(7), object(4)
# memory usage: 62.9+ KB

# %%
# Export the combined DataFrame to a CSV file
combined_data.to_csv('Final Data (No TRREB).csv', index=False)

print("Data exported successfully to 'Final Data (No TRREB).csv'")
# Out:
# Data exported successfully to 'Final Data (No TRREB).csv'

# %% [markdown]
# ### 2. Exploratory Data Analysis

# %% [markdown]
# The data collection/cleaning section above created one single clean csv file, which will be used here.

# %%
df = pd.read_csv('Final Data (No TRREB).csv')

# %%
df.head()
# Out:
#    Listing ID  Source               Address  Bedrooms  Bathrooms  \
# 0  2063459583  Zillow        413 Markham St       1.0        1.0
# 1  2054131263  Zillow        1221 King St W       1.0        1.0
# 2  2079696219  Zillow     47 Lower River St       1.0        1.0
# 3   442326900  Zillow  120 Rowntree Mill Rd       1.0        1.0
# 4   442260890  Zillow   1100 Sheppard Ave W       1.0        1.0
#
#    Living Area (sqft)   Latitude  Longitude            Neighbourhood  \
# 0               900.0  43.660350 -79.410310  Palmerston-Little Italy
# 1               500.0  43.638584 -79.427666           South Parkdale
# 2               500.0  43.656498 -79.355540                Moss Park
# 3               800.0  43.753500 -79.577644            Humber Summit
# 4               626.0  43.751930 -79.466700  York University Heights
#
#    Neighbourhood Rank  Rent Price (CAD)
# 0                 9.0            2400.0
# 1               144.0            2200.0
# 2                69.0            2200.0
# 3               151.0            1645.0
# 4               145.0            2400.0

# %%
df.shape
# Out:
# (731, 11)

# %% [markdown]
# #### 2.1 Outliers

# %% [markdown]
# Let's check for outliers based on the rent price and living area.

# %%
# Plot Rental price vs Living area
plt.figure(figsize=(10, 6))
plt.scatter(df['Living Area (sqft)'], df['Rent Price (CAD)'], color='blue')
plt.xlabel('Living Area (sqft)', fontsize=25)
plt.ylabel('Rent Price (CAD)', fontsize=25)
plt.title('Variations in rental prices based on living area', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.show()

# %% [markdown]
# There seems to be some outliers. They will be checked individualy via going to their listings page and verifiying if it is correct. Also there seems to be only 7 different areas for the Toronto Realistate Board data this my be a problem.

# %%
# Filter for outliers: price above 12000
outliers = df[df['Rent Price (CAD)'] > 12000]

# Display each outlier's information in a single row format
for index, row in outliers.iterrows():
    print(f"URL: {row['Address']}, Price: {row['Rent Price (CAD)']}, Area: {row['Living Area (sqft)']} sqft")
# Out:
# URL: 61 Yorkville Ave, Price: 12968.0, Area: 503.0 sqft

# %% [markdown]
# The 12968 CAD seems to be mistake for that area. So, it will be deleted.

# %%
# Filter out the '61 Yorkville Ave' listing
df = df[df['Rent Price (CAD)'] <= 10000].reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Listing ID          730 non-null    object
#  1   Source              730 non-null    object
#  2   Address             730 non-null    object
#  3   Bedrooms            730 non-null    float64
#  4   Bathrooms           730 non-null    float64
#  5   Living Area (sqft)  730 non-null    float64
#  6   Latitude            730 non-null    float64
#  7   Longitude           730 non-null    float64
#  8   Neighbourhood       730 non-null    object
#  9   Neighbourhood Rank  730 non-null    float64
#  10  Rent Price (CAD)    730 non-null    float64
# dtypes: float64(7), object(4)
# memory usage: 62.9+ KB

# %%
# Update the CSV file
df.to_csv('Final Data (No TRREB).csv', index=False)

print("'Final Data (No TRREB).csv' has been updated successfully")
# Out:
# 'Final Data (No TRREB).csv' has been updated successfully

# %% [markdown]
# #### 2.1 Distribution of Rent Prices

# %%
# Plot the distribution of rental prices
plt.figure(figsize=(10, 7))
sns.histplot(df['Rent Price (CAD)'], kde=True, color='blue', bins=50)
plt.xlabel('Rent Price (CAD)', fontsize=25)
plt.ylabel('Density', fontsize=25)
plt.title('Distribution of Rent Prices', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.show()

# %% [markdown]
# AS seen above, the most common rent price is around 2400$ with normal distribution.

# %% [markdown]
# #### 2.2 Location Distribution of Rent Listings

# %%
# Plot neighborhoods
fig, ax = plt.subplots(figsize=(12, 12))
neighbourhoods.plot(ax=ax, color='lightblue', edgecolor='white')

# Plot listings' locations
plt.scatter(df['Longitude'],df['Latitude'], color='black', s=10, label="Listing Location")

# Add labels and legend
plt.xlabel("Longitude", fontsize=25)
plt.ylabel("Latitude", fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.legend(loc="upper left", frameon=True, edgecolor='black', fontsize=20)
plt.title("Listings Locations on Toronto Neighborhoods", fontsize=25)

plt.show()

# %% [markdown]
# Most of the listings are in downtown Toronto, so when we do the train/test split we will make sure the train, val, and test have the same porportion of listings from downtown.

# %% [markdown]
# #### 2.3 Relations between Features and Target (Rent Price).

# %% [markdown]
# **Living Area and Rent Price**

# %%
# Plot Rental price vs Living area
plt.figure(figsize=(10, 6))
plt.scatter(df['Living Area (sqft)'], df['Rent Price (CAD)'], color='blue')
plt.xlabel('Living Area (sqft)', fontsize=25)
plt.ylabel('Rent Price (CAD)', fontsize=25)
plt.title('Variations in rental prices based on living area', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Define the desired order of sources
priority_source = "TRREB"  # Replace with the specific source you want on top
other_sources = [s for s in df['Source'].unique() if s != priority_source]

# Plot all other sources first
for source_value in other_sources:
    subset = df[df['Source'] == source_value]
    plt.scatter(subset['Living Area (sqft)'], subset['Rent Price (CAD)'], alpha=1, label=source_value)

# Plot the priority source last (on top)
priority_subset = df[df['Source'] == priority_source]
plt.scatter(priority_subset['Living Area (sqft)'], priority_subset['Rent Price (CAD)'], 
            alpha=1, label=priority_source)

plt.xlabel('Living Area (sqft)', fontsize=25)
plt.ylabel('Rent Price (CAD)', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Variations in rental prices based on living area', fontsize=25)
plt.legend(loc="upper left", frameon=True, edgecolor='black', fontsize=15)
plt.show()

# %% [markdown]
# **Number of bedrooms and price**

# %%
# Create the box plot
plt.figure(figsize=(12, 7))
sns.boxplot(data=df, x='Bedrooms', y='Rent Price (CAD)', color='Red')

# Customize the plot
plt.title('Variations in rental prices based on number of bedrooms', fontsize=25)
plt.xlabel('Number of Bedrooms', fontsize=25)
plt.ylabel('Rent Price (CAD)', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=20)

# Show the plot
plt.show()

# %% [markdown]
# **Number of Bathrooms and Rent Price**

# %%
# Create the box plot for Bathrooms
plt.figure(figsize=(12, 7))
sns.boxplot(data=df, x='Bathrooms', y='Rent Price (CAD)', color='Green')

# Customize the plot
plt.title('Variations in rental prices based on number of bathrooms', fontsize=25)
plt.xlabel('Number of Bathrooms', fontsize=25)
plt.ylabel('Rent Price (CAD)', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=20)

# Show the plot
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Listing ID          730 non-null    object
#  1   Source              730 non-null    object
#  2   Address             730 non-null    object
#  3   Bedrooms            730 non-null    float64
#  4   Bathrooms           730 non-null    float64
#  5   Living Area (sqft)  730 non-null    float64
#  6   Latitude            730 non-null    float64
#  7   Longitude           730 non-null    float64
#  8   Neighbourhood       730 non-null    object
#  9   Neighbourhood Rank  730 non-null    float64
#  10  Rent Price (CAD)    730 non-null    float64
# dtypes: float64(7), object(4)
# memory usage: 62.9+ KB

# %% [markdown]
# **Neighbourhood Rank and Rent Price**

# %%
# Calculate the average rental price by neighborhood rank
avg_price_by_rank = df.groupby('Neighbourhood Rank')['Rent Price (CAD)'].mean().reset_index()

# Create the plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=avg_price_by_rank, x='Neighbourhood Rank', y='Rent Price (CAD)', color='blue')

# Customize the plot
plt.title('Average rental prices by neighbourhood rank', fontsize=25)
plt.xlabel('Neighbourhood Rank', fontsize=25)
plt.ylabel('Average Rent Price (CAD)', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=20)

# Show the plot
plt.show()

# %%
plot = sns.jointplot(data=df,
                     x='Neighbourhood Rank',
                     y='Rent Price (CAD)',
                     color='blue', kind='reg',
                     scatter_kws={'s': 20, 'alpha': 0.4}, line_kws={'color': 'black'})

# Adjust figure size
plot.figure.set_size_inches(9, 7)

# Set axis labels font size
plot.ax_joint.set_xlabel('Neighbourhood Rank', fontsize=25)
plot.ax_joint.set_ylabel('Rent Price (CAD)', fontsize=25)

# Set tick labels font size
plot.ax_joint.tick_params(axis='both', which='major', labelsize=20)

plt.show()

# %% [markdown]
# The trend is not always true but it seems that the expensive averages are in the higher ranked neighbourhoods.

# %% [markdown]
# #### 2.4 Additional EDA

# %% [markdown]
# Let's see how the rental prices vary compared to the distance to U of T!

# %%
# Define conversion factors for degrees to kilometers
lat_km_per_deg = 111  # 1 degree of latitude is approximately 111 km
lon_km_per_deg = lambda lat: 111 * np.cos(np.radians(lat))  # Longitude scaling by latitude

# U of T's coordinates
u_of_t_lat = 43.66362427073241
u_of_t_lon = -79.39586940102717

# Define functions for Haversine and Manhattan distances
def manual_haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    r = 6371  # Radius of Earth in kilometers
    return c * r

def manual_manhattan_distance(lat1, lon1, lat2, lon2):
    lon_km = lon_km_per_deg((lat1 + lat2) / 2)  # Average latitude for accuracy
    return (abs(lat1 - lat2) * lat_km_per_deg) + (abs(lon1 - lon2) * lon_km)

# Calculate distances and add to the dataframe
df['Haversine Distance to U of T (km)'] = df.apply(
    lambda row: manual_haversine(row['Latitude'], row['Longitude'], u_of_t_lat, u_of_t_lon), axis=1
)
df['Manhattan Distance to U of T (km)'] = df.apply(
    lambda row: manual_manhattan_distance(row['Latitude'], row['Longitude'], u_of_t_lat, u_of_t_lon), axis=1
)

# %%
# Bin distances into 500m bins and calculate the average rent price for each bin
df['Haversine Distance Bin (km)'] = (df['Haversine Distance to U of T (km)'] // 0.5) * 0.5
df['Manhattan Distance Bin (km)'] = (df['Manhattan Distance to U of T (km)'] // 0.5) * 0.5

# Calculate the average rent price for each bin
haversine_avg = df.groupby('Haversine Distance Bin (km)')['Rent Price (CAD)'].mean()
manhattan_avg = df.groupby('Manhattan Distance Bin (km)')['Rent Price (CAD)'].mean()

# Plot the average rent price for each distance bin
plt.figure(figsize=(12, 6))
plt.plot(haversine_avg.index, haversine_avg.values, marker='o', label="Haversine Distance", alpha=0.8)
plt.plot(manhattan_avg.index, manhattan_avg.values, marker='o', label="Manhattan Distance", alpha=0.8)
plt.xlabel('Distance to U of T (km)', fontsize=22)
plt.ylabel('Average Rent Price (CAD)', fontsize=22)
plt.title('Differences in average rental prices based on the distance to UofT', fontsize=22)
plt.legend(fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.show()

# %% [markdown]
# ### 3. Feature Engineering

# %%
df = pd.read_csv('Final Data (No TRREB).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Listing ID          730 non-null    object
#  1   Source              730 non-null    object
#  2   Address             730 non-null    object
#  3   Bedrooms            730 non-null    float64
#  4   Bathrooms           730 non-null    float64
#  5   Living Area (sqft)  730 non-null    float64
#  6   Latitude            730 non-null    float64
#  7   Longitude           730 non-null    float64
#  8   Neighbourhood       730 non-null    object
#  9   Neighbourhood Rank  730 non-null    float64
#  10  Rent Price (CAD)    730 non-null    float64
# dtypes: float64(7), object(4)
# memory usage: 62.9+ KB

# %% [markdown]
# #### 3.1 Split the data (train/test)

# %% [markdown]
# The train, val, and test should be divided evenly geographically. Therefore, the data is divided into clusters so that the resulting sets will have a proportional amount of data from each cluster.

# %%
# Define the number of clusters (e.g., 4 clusters)
num_clusters = 4

# Perform clustering on latitude and longitude
kmeans = KMeans(n_clusters=num_clusters, random_state=4,  n_init=20)
df['Cluster'] = kmeans.fit_predict(df[['Latitude', 'Longitude']])

# Plot neighborhoods
fig, ax = plt.subplots(figsize=(12, 12))
neighbourhoods.plot(ax=ax, color='lightblue', edgecolor='white')

# Define colors for each cluster
colors = {0: 'blue', 1: 'green', 2: 'red', 3: 'orange'}

# Plot listings' locations
plt.scatter(df['Longitude'],df['Latitude'], c=df['Cluster'].map(colors), s=10)

# Add labels and legend
plt.xlabel("Longitude", fontsize=25)
plt.ylabel("Latitude", fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.legend(handles=[mpatches.Patch(color=color, label=f'Cluster {i}') for i, color in colors.items()],
           loc="upper left", frameon=True, edgecolor='black', fontsize=20)
plt.title("Listings Locations with clustering", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Listings Locations with clustering')

# %% [markdown]
# Dividing the dataset into: 80% Training - 20% Test

# %%
train, test = train_test_split(df, train_size=0.8, stratify=df['Cluster'], random_state=4)

# %%
print(f"Train Size: {len(train)}, Test Size: {len(test)}")
# Out:
# Train Size: 584, Test Size: 146

# %% [markdown]
# **Training set distribution**

# %%
# Plot neighborhoods
fig, ax = plt.subplots(figsize=(12, 12))
neighbourhoods.plot(ax=ax, color='lightblue', edgecolor='white')

# Define colors for each cluster
colors = {0: 'blue', 1: 'green', 2: 'red', 3: 'orange'}

# Plot listings' locations
plt.scatter(train['Longitude'],train['Latitude'], c=train['Cluster'].map(colors), s=10)

# Add labels and legend
plt.xlabel("Longitude", fontsize=25)
plt.ylabel("Latitude", fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.legend(handles=[mpatches.Patch(color=color, label=f'Cluster {i}') for i, color in colors.items()],
           loc="upper left", frameon=True, edgecolor='black', fontsize=20)
plt.title("Listings Locations with clustering (train set)", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Listings Locations with clustering (train set)')

# %% [markdown]
# **Test set distribution**

# %%
# Plot neighborhoods
fig, ax = plt.subplots(figsize=(12, 12))
neighbourhoods.plot(ax=ax, color='lightblue', edgecolor='white')

# Define colors for each cluster
colors = {0: 'blue', 1: 'green', 2: 'red', 3: 'orange'}

# Plot listings' locations
plt.scatter(test['Longitude'],test['Latitude'], c=test['Cluster'].map(colors), s=10)

# Add labels and legend
plt.xlabel("Longitude", fontsize=25)
plt.ylabel("Latitude", fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.legend(handles=[mpatches.Patch(color=color, label=f'Cluster {i}') for i, color in colors.items()],
           loc="upper left", frameon=True, edgecolor='black', fontsize=20)
plt.title("Listings Locations with clustering (test set)", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Listings Locations with clustering (test set)')

# %% [markdown]
# #### 3.2 Functions

# %% [markdown]
# In this section, several functions are created. Those functions will be used in the modeling.

# %%
def create_features(df):
    """
    Creates various columns (features) in the DataFrame.

    Parameters:
        df (DataFrame): The original DataFrame.

    Returns:
        df_copy (DataFrame): A copy of the original DataFrame with all new columns (features).
    """
    df_copy = df.copy()

    # Extract Longitude and Latitude
    location_data = df_copy[["Longitude", "Latitude"]]

    # Scale Longitude and Latitude before PCA
    scaler = StandardScaler()
    location_scaled = scaler.fit_transform(location_data)

    # Perform PCA and add PC1 to the dataset
    pca = PCA(n_components=1)
    df_copy['PC1'] = pca.fit_transform(location_scaled)
    
    return df_copy

# %%
def preprocess_data(df):

    """
    Removes specified redundant columns from the DataFrame and scale specified columns.

    Parameters:
        df (DataFrame): The Original DataFrame.

    Returns:
        df_copy (DataFrame): A copy of the original DataFrame after processing.

    """
    df_copy = df.copy()

    # Drop unnecessary columns
    columns_to_drop = ['Address', 'Source', 'Latitude', 'Longitude', 'Neighbourhood', 'Cluster']
    df_copy = df_copy.drop(columns=columns_to_drop)
    
    # Identify numeric columns that need scaling
    columns_to_scale = ['Bedrooms', 'Bathrooms', 'Living Area (sqft)','Neighbourhood Rank', 'PC1']
    
    # Fit the scaler on the training data
    scaler = StandardScaler()
    df_copy[columns_to_scale] = scaler.fit_transform(df_copy[columns_to_scale])
    
    return df_copy

# %%
def select_features(df, target=None, features=None):

    """
    Select specified columns from the DataFrames.

    Parameters:
        df (DataFrame): The Original DataFrame.

    Returns:
        df_copy (DataFrame): A copy of the original DataFrame with specified columns only.

    """
    df_copy = df.copy()
    
    if target:
        return df_copy[target + features]
    else:
        return df_copy[features]

# %% [markdown]
# ### 4. Modeling

# %% [markdown]
# #### 4.1 Simple Model (Always Predicts the Mean)

# %%
def simple_model(train):

    """
    Train and fit a simple model on the training dataset and return R² and RMSE of the validation dataset.

    Parameters:
        train (DataFrame): The training DataFrame.
        val (DataFrame): The validation DataFrame.

    Returns:
         (float): R² score of the validation dataset.
    """

    # Calculate the mean rent from the training set
    mean_rent = train['Rent Price (CAD)'].mean()

    y_train = train['Rent Price (CAD)']

    y_train_pred = np.full_like(train['Rent Price (CAD)'], fill_value=mean_rent)

    # Evaluate the model on the training set
    train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
    train_r2 = r2_score(y_train, y_train_pred)

    # Print results
    print("Baseline Model Performance:")
    print(f"RMSE: {train_rmse:.2f}, R²: {train_r2:.2f}")

    return

# %%
simple_model(train)
# Out:
# Baseline Model Performance:
# RMSE: 803.34, R²: 0.00

# %% [markdown]
# #### 4.2 Linear Model

# %%
def linear_model(df,target,features,n_splits=4):

    """
    Perform stratified cross-validation on a linear model with stratification based on a cluster column..

    Parameters:
        df (DataFrame): The entire training DataFrame.
        target (str): The target column name.
        features (list): The feature column names.
        n_splits (int): The number of folds for cross-validation.

    Returns:
        mean_cv_rmse (float): Mean RMSE score across validation folds.
        mean_cv_r2 (float): Mean R² score across validation folds.
        models (list): List of models trained on each fold.
    """
    # Initialize StratifiedKFold
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=4)

    val_r2_scores = []
    val_rmse_scores = []
    models = []

    print(f"Performing {n_splits}-Fold Stratified Cross-Validation...")

    for fold, (train_idx, val_idx) in enumerate(skf.split(df, df['Cluster'])):
        
        train = df.iloc[train_idx]
        val = df.iloc[val_idx]

        # Apply data preprocessing and feature selection for each fold
        train = create_features(train)      # Avoiding data leakage
        val = create_features(val)

        train = preprocess_data(train)      # Avoiding data leakage
        val = preprocess_data(val)

        train = select_features(train, target, features)
        val = select_features(val, target, features)

        # Separate features and target
        X_train = train.drop(target, axis = 1)
        y_train = train.loc[:, target]

        X_val = val.drop(target, axis = 1)
        y_val = val.loc[:, target]

        # Train the model
        model = LinearRegression(fit_intercept=True)
        model.fit(X_train, y_train)

        # Store the model for later use
        models.append(model)

        # Predictions
        y_val_pred = model.predict(X_val)

        # Evaluate performance
        val_r2 = r2_score(y_val, y_val_pred)
        val_r2_scores.append(val_r2)

        val_rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
        val_rmse_scores.append(val_rmse)

        print(f"Fold {fold + 1}: Validation RMSE: {val_rmse:.2f}, Validation R² = {val_r2:.2f}")

    # Compute the mean RMSE and R² score across folds
    mean_cv_r2 = np.mean(val_r2_scores)
    mean_cv_rmse = np.mean(val_rmse_scores)

    print("Linear Regression Model Performance:")
    print(f"\nMean Validation RMSE Across Folds: {mean_cv_rmse:.2f}")
    print(f"\nMean Validation R² Across Folds: {mean_cv_r2:.2f}")
    
    return mean_cv_rmse, mean_cv_r2, models

# %%
features = ['Bedrooms', 'Bathrooms', 'Living Area (sqft)', 'Neighbourhood Rank', 'PC1']
target = ['Rent Price (CAD)']
linear_model(df,target,features,4)
# Out:
# Performing 4-Fold Stratified Cross-Validation...
# Fold 1: Validation RMSE: 528.36, Validation R² = 0.50
# Fold 2: Validation RMSE: 624.98, Validation R² = 0.57
# Fold 3: Validation RMSE: 482.12, Validation R² = 0.63
# Fold 4: Validation RMSE: 460.69, Validation R² = 0.61
# Linear Regression Model Performance:
#
# Mean Validation RMSE Across Folds: 524.04
#
# Mean Validation R² Across Folds: 0.58
# (524.0379564511321,
#  0.5766138959815932,
#  [LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression()])

# %% [markdown]
# Let's see the correlation matrix

# %%
temporary = create_features(train)
temporary = preprocess_data(temporary)

plt.figure(figsize=(10, 6))
cm_plot = sns.heatmap(temporary.select_dtypes(['number']).corr(), annot=True, cmap='coolwarm', fmt='.2f', annot_kws={'size': 20})
plt.title('Correlation Matrix', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=25)

# Adjust the colorbar label font size
colorbar = cm_plot.collections[0].colorbar
colorbar.ax.tick_params(labelsize=20)

plt.show()

# %% [markdown]
# #### 4.3 Random Forest Model

# %%
def rf_model(df, target, features, param_distributions=None, n_iter=10):
    """
    Train and optimize the Random Forest model using RandomizedSearchCV.

    Parameters:
        df (DataFrame): The entire training DataFrame.
        target (str): The target column name.
        features (list): The feature column names.
        param_distributions (dict): The hyperparameter grid for randomized search.
        n_iter (int): Number of parameter combinations to try.

    Returns:
        dict: Best model and best hyperparameters.
    """
    if param_distributions is None:
        param_distributions = {
            'n_estimators': [50, 100, 200],
            'max_depth': [5, 10, 20, 30],
            'min_samples_split': [2, 5, 20, 40],
            'min_samples_leaf': [1, 2, 5]
            }

    train, val = train_test_split(df, train_size=0.65, stratify=df['Cluster'], random_state=4)

    train = create_features(train)      # Avoiding data leakage
    val = create_features(val)

    train = preprocess_data(train)      # Avoiding data leakage
    val = preprocess_data(val)

    train = select_features(train, target, features)
    val = select_features(val, target, features)

    X_train = train.drop(target, axis = 1)
    y_train = train.loc[:, target]

    X_val = val.drop(target, axis = 1)
    y_val = val.loc[:, target]

    # Initialize Random Forest and RandomizedSearchCV
    model = RandomForestRegressor(random_state=4)
    random_search = RandomizedSearchCV(
        estimator=model,
        param_distributions=param_distributions,
        n_iter=n_iter,
        scoring='r2',
        cv=KFold(n_splits=3),
        random_state=4
    )
    
    # Fit the RandomizedSearchCV
    random_search.fit(X_train, y_train)

    # Get the best model, parameters, and cross-validation score
    best_model = random_search.best_estimator_
    best_params = random_search.best_params_
    best_cv_r2 = random_search.best_score_

    # Validate on the hold-out validation set
    y_val_pred = best_model.predict(X_val)
    val_r2 = r2_score(y_val, y_val_pred)
    val_rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))

    print(f"Best Parameters: {best_params}")
    print(f"Best CV R² Score: {best_cv_r2:.2f}")
    print(f"Validation R² Score: {val_r2:.2f}")
    print(f"Validation RMSE: {val_rmse:.2f}")

    # Extracting features importance
    feature_importances = best_model.feature_importances_
    feature_names = X_train.columns
    importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
    importance_df = importance_df.sort_values(by='Importance', ascending=False)

    # Plot features importance
    plt.barh(importance_df['Feature'], importance_df['Importance'])
    plt.xlabel('Importance')
    plt.ylabel('Feature')
    plt.title('Feature Importance')
    plt.show()

    return  best_model, best_params

# %%
features = ['Bedrooms', 'Bathrooms', 'Living Area (sqft)', 'Neighbourhood Rank', 'PC1']
target = ['Rent Price (CAD)']
model, hyperparameter = rf_model(train,target,features)
# Out:
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_depth': 5}
# Best CV R² Score: 0.58
# Validation R² Score: 0.60
# Validation RMSE: 483.30

# %% [markdown]
# #### 4.4 Final Model

# %% [markdown]
# The follwoing function is for the final linear model and final random forest model on the test dataset.

# %%
def final_linear_model(train,test,target,features):

    """
    Train and fit the final linear model on the entire training dataset and return R² and RMSE of the test dataset.

    Parameters:
        train (DataFrame): The entire training DataFrame.
        test (DataFrame): The validation DataFrame.
        target (str): The target column name.
        features (list): The feature column names.

    Returns:
         model: Final Linear model.
    """

    train = create_features(train)      # Avoiding data leakage
    test = create_features(test)

    train = preprocess_data(train)      # Avoiding data leakage
    test = preprocess_data(test)

    train = select_features(train,target,features)
    test = select_features(test,target,features)

    X_train = train.drop(target, axis = 1)
    y_train = train.loc[:, target]

    X_test = test.drop(target, axis = 1)
    y_test = test.loc[:, target]

    model = LinearRegression(fit_intercept=True)
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Evaluate the model on the training set
    train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
    train_r2 = r2_score(y_train, y_train_pred)

    # Evaluate the model on the validation set
    test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
    test_r2 = r2_score(y_test, y_test_pred)

    # Print results
    print("Final Linear Regression Model Performance:")
    print(f"Training RMSE: {train_rmse:.2f}, Training R²: {train_r2:.2f}")
    print(f"Test RMSE: {test_rmse:.2f}, Test R²: {test_r2:.2f}")

    return model, y_test_pred, y_test

# %%
def final_rf_model(train, test, target, features, param_distributions, n_iter=10):

    """
    Train and fit the final model on the entire training dataset.

    Parameters:
        train (DataFrame): The entire training DataFrame.
        test (DataFrame): The test DataFrame.
        target (str): The target column name.
        features (list): The feature column names.
        param_distributions (dict): The optimized hyperparameter grid.
        n_iter (int): Number of parameter combinations to try.

    Returns:
        best_model: Final random forest model.
    """

    train = create_features(train)      # Avoiding data leakage
    test = create_features(test)

    train = preprocess_data(train)      # Avoiding data leakage
    test = preprocess_data(test)

    train = select_features(train, target, features)
    test = select_features(test, target, features)

    X_train = train.drop(target, axis = 1)
    y_train = train.loc[:, target]

    X_test = test.drop(target, axis = 1)
    y_test = test.loc[:, target]

    model = RandomForestRegressor(random_state=44)
    random_search = RandomizedSearchCV(
        estimator=model,
        param_distributions=param_distributions,
        n_iter=n_iter,
        scoring='r2',
        cv=KFold(n_splits=3),
        random_state=4
    )
    
    random_search.fit(X_train, y_train)

    best_model = random_search.best_estimator_

    y_train_pred = best_model.predict(X_train)
    y_test_pred = best_model.predict(X_test)

    # Evaluate the model on the entire training set
    train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
    train_r2 = r2_score(y_train, y_train_pred)

    # Evaluate the model on the validation set
    test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
    test_r2 = r2_score(y_test, y_test_pred)

    # Print results
    print("Final Random Forest Model Performance:")
    print(f"Training RMSE: {train_rmse:.2f}, Training R²: {train_r2:.2f}")
    print(f"Test RMSE: {test_rmse:.2f}, Test R²: {test_r2:.2f}")

    return  best_model, y_test_pred, y_test

# %% [markdown]
# ### 5. Prediction on the test dataset

# %% [markdown]
# DO NOT RUN NOW. RUN ONLY AFTER SELECTING THE MODEL.

# %%
features = ['Bedrooms', 'Bathrooms', 'Living Area (sqft)', 'Neighbourhood Rank', 'PC1']
target = ['Rent Price (CAD)']
param_distributions = {
            'n_estimators': [200],
            'max_depth': [5],
            'min_samples_split': [5],
            'min_samples_leaf': [5]}
                                 
best_rf_model, y_test_pred_rf, y_test_rf = final_rf_model(train, test, target, features, param_distributions)
print('---------------------------------------------------')
best_linear_model, y_test_pred_lr, y_test_lr  = final_linear_model (train,test,target,features)
# Out:
# Final Random Forest Model Performance:
# Training RMSE: 423.79, Training R²: 0.72
# Test RMSE: 471.89, Test R²: 0.69
# ---------------------------------------------------
# Final Linear Regression Model Performance:
# Training RMSE: 510.57, Training R²: 0.60
# Test RMSE: 538.83, Test R²: 0.59

# %% [markdown]
# ### 6. Visualizing the final predictions

# %%
def plot_predictions_vs_actual(y_pred_rf, y_actual_rf, y_pred_lr, y_actual_lr):

    plt.figure(figsize=(8, 8))

    y_actual_rf = np.ravel(y_actual_rf)
    y_pred_rf = np.ravel(y_pred_rf)

    y_actual_lr = np.ravel(y_actual_lr)
    y_pred_lr = np.ravel(y_pred_lr)
    
    # Plot predicted vs actual values
    plt.scatter(x = y_pred_rf, y = y_actual_rf, color='blue', alpha=0.5, label='Random Forest Model',s=40)
    plt.scatter(x = y_pred_lr, y = y_actual_lr, color='green', alpha=0.5, label='Linear Model',s=40)
    
    # Add labels and title
    plt.xlabel('Actual Rent Price (CAD)', fontsize=22)
    plt.ylabel('Predicted Rent Price (CAD)', fontsize=22)
    plt.title(f'Actual vs Predicted Rent Prices', fontsize=22)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.legend(loc="upper left", frameon=True, edgecolor='black', fontsize=14)

    # Draw the 45-degree line: y = x
    plt.plot([0, 10000], [0, 10000], color='red', linestyle='--', linewidth=2)
    plt.plot([0, 9500], [500, 10000], color='red', linestyle='--', linewidth=1)
    plt.plot([500, 10000], [0, 9500], color='red', linestyle='--', linewidth=1)

    # Add a label with an arrow pointing to the y=x line
    plt.annotate('Predicted = Actual', 
             xy=(0.58, 0.58), xycoords='axes fraction',  # Position the label
             xytext=(0.65, 0.2), textcoords='axes fraction',  # Position the arrow
             arrowprops=dict(facecolor='black', arrowstyle='->'), fontsize=16)
    
    plt.xlim([0,10000])
    plt.ylim([0,10000])

    plt.show()

# %%
# Plot actual vs predicted values
plot_predictions_vs_actual(y_test_pred_rf, y_test_rf, y_test_pred_lr, y_test_lr)

# %% [markdown]
# ### 7. Input Function

# %%
def input_function(model, pca, neighbourhoods_gdf, scaler, listings_df):
    """
    Input function for apartment rental prediction with nearest listings.
    
    Args:
        model: Trained machine learning model.
        pca: Trained PCA object for dimensionality reduction.
        neighbourhoods_gdf: GeoDataFrame of neighborhood boundaries with ranks.
        scaler: Trained scaler used for feature scaling.
        listings_df: DataFrame containing all apartment listings (including bedrooms, coordinates, etc.).
    
    Returns:
        Predicted rental price and nearest apartment listings.
    """
    print("Enter the apartment details:")
    try:
        # Gather inputs from the user

        living_area = float(input("Living area (sqft): "))
        if living_area <= 0 or living_area > 3000:
            print(f"Warning: The living area of {living_area} sqft seems suspicious (must be between 0 and 3000 sqft).")

        bedrooms = float(input("Number of bedrooms: "))
        valid_bedrooms = {0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6}
        if bedrooms not in valid_bedrooms:
            print(f"Warning: The number of bedrooms ({bedrooms}) seems unusual (valid values: {valid_bedrooms}).")

        bathrooms = float(input("Number of bathrooms: "))
        if not bathrooms.is_integer() or bathrooms < 0 or bathrooms > 6:
            print(f"Warning: The number of bathrooms ({bathrooms}) seems suspicious (must be an integer between 0 and 6).")
        
        
        lat_lon = input("Enter Latitude, Longitude (comma-separated): ").strip()
        # Split the latitude and longitude string into two separate numbers
        latitude, longitude = map(float, lat_lon.split(','))

        # Step 1: Calculate PC1 for the location
        location = np.array([[longitude, latitude]])
        pc1 = pca.transform(location)[0][0]

        # Step 2: Retrieve the neighborhood rank based on the coordinates
        point = Point(longitude, latitude)  # Create a Shapely point
        neighborhood_match = neighbourhoods_gdf[neighbourhoods_gdf.contains(point)]
        
        if neighborhood_match.empty:
            neighbourhood_rank = -1  # Assign a default rank
            print("Warning: Location is outside defined neighborhoods!")
        else:
            neighbourhood_rank = neighborhood_match.iloc[0]['Neighbourhood Rank']

        # Step 3: Prepare the features for prediction
        features = pd.DataFrame([{
            'Bedrooms': bedrooms,
            'Bathrooms': bathrooms,
            'Neighbourhood Rank': neighbourhood_rank,
            'Living Area (sqft)': living_area,
            'PC1': pc1
        }])
        
        # Scale the features using the trained scaler
        features_scaled = scaler.transform(features)
        
        # Step 4: Predict the rental price
        predicted_price = model.predict(features_scaled)
        # Convert predicted_price to a scalar float
        predicted_price_value = float(predicted_price[0])  # Explicitly cast to float
        print(f"\nPredicted Rental Price: ${predicted_price_value:,.2f} CAD")
        
        # Step 5: Find the 5 nearest apartments with the same number of bedrooms
        input_coords = (latitude, longitude)
        listings_df['Distance'] = listings_df.apply(
            lambda row: haversine(input_coords, (row['Latitude'], row['Longitude'])), axis=1
        )
        
        # Filter for apartments with the same number of bedrooms
        filtered_listings = listings_df[listings_df['Bedrooms'] == bedrooms]
        
        # Sort by distance and select the 5 closest apartments
        nearest_listings = filtered_listings.nsmallest(5, 'Distance').copy()
        
        # Round the distance to 1 decimal place and append ' km'
        nearest_listings['Distance'] = nearest_listings['Distance'].round(1).astype(str) + ' km'
        
        print("\n5 Nearest Listings with the Same Number of Bedrooms:")
        print(nearest_listings[['Address', 'Rent Price (CAD)', 'Distance']])
        
        return None
    
    except ValueError as e:
        print(f"Invalid input: {e}")
        return None

# %%
neighbourhoods_gdf = neighbourhoods.copy()
neighbourhoods_gdf["Neighbourhood Rank"] = neighbourhoods_gdf["AREA_NA7"].map(neighbourhood_ranking)

# Import all dataset
input_df = pd.read_csv('Final Data.csv')

# Extract Longitude and Latitude
location_data = input_df[["Longitude", "Latitude"]]

# Scale Longitude and Latitude before PCA
input_PCA_scaler = StandardScaler()
location_scaled = input_PCA_scaler.fit_transform(location_data)

# Perform PCA and add PC1 to the dataset
input_pca = PCA(n_components=1)
input_df['PC1'] = input_pca.fit_transform(location_scaled)

# Drop unnecessary columns
columns_to_drop = ['Listing ID', 'Source', 'Neighbourhood']
input_df = input_df.drop(columns=columns_to_drop)
    
# Identify numeric columns that need scaling
columns_to_scale = ['Bedrooms', 'Bathrooms', 'Neighbourhood Rank', 'Living Area (sqft)', 'PC1']
    
# Fit the scaler on the entire data
input_scaler = StandardScaler()
scaled_features = input_scaler.fit_transform(input_df[columns_to_scale])

# %%
# Call the input function using the best random forest model!
input_function(best_rf_model, input_pca, neighbourhoods_gdf, input_scaler, input_df)
# Out:
# Enter the apartment details:
#
# Predicted Rental Price: $3,062.41 CAD
#
# 5 Nearest Listings with the Same Number of Bedrooms:
#                                   Address  Rent Price (CAD) Distance
# 92                        25 Gemshaw Cres            2150.0   4.1 km
# 3881  68 Corporate Drive, Scarborough, ON            2795.0   5.1 km
# 3891      68 Corporate Drive, Toronto, ON            2800.0   5.1 km
# 3946   2365 Kennedy Road, Scarborough, ON            3050.0   5.7 km
# 3731    238 BONIS Avenue, Scarborough, ON            2400.0   5.7 km

# %%
# Call the input function using the best linear model!
input_function(best_linear_model, input_pca, neighbourhoods_gdf, input_scaler, input_df)
# Out:
# Enter the apartment details:
#
# Predicted Rental Price: $5,274.24 CAD
#
# 5 Nearest Listings with the Same Number of Bedrooms:
#                                   Address  Rent Price (CAD) Distance
# 92                        25 Gemshaw Cres            2150.0   4.1 km
# 3881  68 Corporate Drive, Scarborough, ON            2795.0   5.1 km
# 3891      68 Corporate Drive, Toronto, ON            2800.0   5.1 km
# 3946   2365 Kennedy Road, Scarborough, ON            3050.0   5.7 km
# 3731    238 BONIS Avenue, Scarborough, ON            2400.0   5.7 km
